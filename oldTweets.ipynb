# %%
import GetOldTweets3 as got
import numpy as np
import pandas as pd
import datetime
import time

# %%
def get_month_tweets2(month,query,start_day=1):
    date_date = datetime.date.today().replace(day=start_day).replace(month=month)
    next_date = date_date + datetime.timedelta(days=1)

    next_month = datetime.date.today().replace(day=28).replace(month=month)\
    + datetime.timedelta(days=4)
    until_date= next_month - datetime.timedelta(days=next_month.day)
    until_date = until_date.strftime("%Y-%m-%d")
    
    today = datetime.date.today().strftime("%Y-%m-%d")
    
    while date_date.strftime("%Y-%m-%d") <= until_date and date_date.strftime("%Y-%m-%d") < today:
        incomplete = True
        while incomplete:
            try:
                tweetCriteria = got.manager.TweetCriteria().setQuerySearch(query)\
                .setSince(date_date.strftime("%Y-%m-%d")).setUntil(next_date.strftime("%Y-%m-%d"))
                # Creation of list that contains all tweets
                tweets = got.manager.TweetManager.getTweets(tweetCriteria)
                # Creating list of chosen tweet data
                text_tweets = [[tweet.id,tweet.date,tweet.username, tweet.text,tweet.hashtags,tweet.geo,\
                                tweet.retweets,tweet.favorites,tweet.mentions,tweet.to] for tweet in tweets]

                df = pd.DataFrame(text_tweets, columns=["id","timestamp","username","text","hashtags","geo","retweets","favorites","mentions","to"])
                df["date"] = df.timestamp.dt.date

                store_csv2(df,month)

                print(date_date.strftime("%Y-%m-%d"), len(text_tweets))
                date_date = date_date + datetime.timedelta(days=1)
                next_date = next_date + datetime.timedelta(days=1)
                
                incomplete = False
                
            except:
                print("Request error")
                time.sleep(60*1)
    
    df = pd.read_csv(f'data/census_tweets_month_{month}.csv')
    return df

def store_csv2(df,month):
    df.to_csv(f'data/census_tweets_month_{month}.csv',mode = 'a', header= False, index = False)

# %%
may = pd.read_csv("data/census_tweets_month_5.csv", parse_dates=["date"]).sort_values(by=["date"],ascending=False)
print(may.date.max())
may.head()
# Out:
# 2020-05-08 00:00:00
#                        id                  timestamp         username  \
# 9617  1258547161807142913  2020-05-08 00:00:00+00:00      stlouispark
# 9036  1258839556066914305  2020-05-08 19:21:52+00:00   CountTheNation
# 9060  1258834510063509504  2020-05-08 19:01:49+00:00   countyplanning
# 9059  1258834898602938373  2020-05-08 19:03:22+00:00  ElisabethLareau
# 9058  1258835165968826369  2020-05-08 19:04:26+00:00  Esteban51442005
#
#                                                    text  \
# 9617  We're moving on up! 73.5% of St. Louis Park ho...
# 9036  As of 5/08 California’s #2020Census participat...
# 9060  This week, five Cuyahoga County communities ex...
# 9059  only 10 minutes for the next 10 years! The #20...
# 9058  Only 10 minutes for the next 10 years! The #20...
#
#                          hashtags  geo  retweets  favorites  \
# 9617          #2020Census #Census  NaN         0          1
# 9036                  #2020Census  NaN         1          7
# 9060  #2020Census #CuyahogaCounts  NaN         1          2
# 9059   #2020census #getcountednyc  NaN         1          1
# 9058   #2020Census #GetCountedNYC  NaN         0          0
#
#                                            mentions   to       date
# 9617                                @uscensusbureau  NaN 2020-05-08
# 9036                                            NaN  NaN 2020-05-08
# 9060  @BHVillageOH @Independence_OH @SevenHillsCity  NaN 2020-05-08
# 9059                                            NaN  NaN 2020-05-08
# 9058                                            NaN  NaN 2020-05-08

# %%
text_query = "#2020census OR #census2020"
df = get_month_tweets2(5,text_query,9)
df
# Out:
# 2020-05-09 415
# 2020-05-10 241
# 2020-05-11 746
#                         id                  timestamp         username  \
# 0      1256372334086291457  2020-05-01 23:58:01+00:00   ForOurFutureNV
# 1      1256372275143749634  2020-05-01 23:57:47+00:00         robachma
# 2      1256372204947812356  2020-05-01 23:57:30+00:00    ISRAELPROPHET
# 3      1256372053009223682  2020-05-01 23:56:54+00:00   ISRAELPROPHET1
# 4      1256371553698078722  2020-05-01 23:54:55+00:00  CityFortBraggCA
# ...                    ...                        ...              ...
# 11015  1259635604624719880  2020-05-11 00:05:05+00:00  OklandPrkEvents
# 11016  1259635604545028098  2020-05-11 00:05:05+00:00  CityOaklandPark
# 11017  1259635133373730817  2020-05-11 00:03:13+00:00     couldbekelly
# 11018  1259634506929242121  2020-05-11 00:00:43+00:00             VCFD
# 11019  1259634480853155845  2020-05-11 00:00:37+00:00     TechGoesHome
#
#                                                     text  \
# 0      Did you complete your #2020Census yet? Did you...
# 1                                           #2020Census
# 2      Message: Why respond to the #2020Census? Censu...
# 3      Message: Why respond to the #2020Census? Censu...
# 4      Did you know the #2020census is required by th...
# ...                                                  ...
# 11015  What matters to you? Schools? Transportation? ...
# 11016  What matters to you? Schools? Transportation? ...
# 11017                Why the census matters #2020Census
# 11018  Don't forget to fill out your #2020Census, a 9...
# 11019  Haven't completed the #2020Census? Check your ...
#
#                                     hashtags  geo  retweets  favorites  \
# 0                                #2020Census  NaN         7          9
# 1                                #2020Census  NaN         0          1
# 2                                #2020Census  NaN         0          0
# 3                                #2020Census  NaN         1          1
# 4                   #2020census #censusfacts  NaN         0          2
# ...                                      ...  ...       ...        ...
# 11015            #shapeourfuture #2020census  NaN         0          0
# 11016            #shapeourfuture #2020census  NaN         0          0
# 11017                            #2020Census  NaN         1         14
# 11018  #2020Census #BeCounted #VenturaCounty  NaN         0          6
# 11019     #2020Census #TGHCounts #MassCounts  NaN         1          0
#
#       mentions               to        date
# 0          NaN              NaN  2020-05-01
# 1          NaN  GregMartinMusic  2020-05-01
# 2          NaN              NaN  2020-05-01
# 3          NaN              NaN  2020-05-01
# 4          NaN              NaN  2020-05-01
# ...        ...              ...         ...
# 11015      NaN              NaN  2020-05-11
# 11016      NaN              NaN  2020-05-11
# 11017      NaN              NaN  2020-05-11
# 11018      NaN              NaN  2020-05-11
# 11019      NaN              NaN  2020-05-11
#
# [11020 rows x 11 columns]
